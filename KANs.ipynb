# %%
from kan import *
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=0)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# (torch.Size([1000, 2]), torch.Size([1000, 1]))

# %%
# plot KAN at initialization
model(dataset['train_input']);
model.plot(beta=100)

# %%
# train the model
model.train(dataset, steps=20, lamb=0.01, lamb_entropy=10.);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # train the model
# ----> 2 model.train(dataset, steps=20, lamb=0.01, lamb_entropy=10.);
#
# TypeError: Module.train() got an unexpected keyword argument 'steps'

# %%
model.plot()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.plot()
#
# File c:\Users\chait\AppData\Local\Programs\Python\Python313\Lib\site-packages\kan\MultKAN.py:1065, in MultKAN.plot(self, folder, beta, metric, scale, tick, sample, in_vars, out_vars, title, varscale)
#    1063 if self.acts == None:
#    1064     if self.cache_data == None:
# -> 1065         raise Exception('model hasn\'t seen any data yet.')
#    1066     self.forward(self.cache_data)
#    1068 if metric == 'backward':
#
# Exception: model hasn't seen any data yet.

# %%
model.prune()
model.plot(mask=True)

# %%
model = model.prune()
model(dataset['train_input'])
model.plot()

# %%
model.train(dataset, opt="LBFGS", steps=50);

# %%
model.symbolic_formula()[0][0]
